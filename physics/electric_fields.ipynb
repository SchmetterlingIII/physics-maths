# %% [markdown]
# <a href="https://colab.research.google.com/github/SchmetterlingIII/physics-maths/blob/main/physics/electric_fields.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Holistic Intention**: To be able to code out small physics things in Python as I review my approach to the computational physics olympiad and try to explain that. How do I explain that well? How do I develop that.

# %% [markdown]
# I am trying to model out the electric field of a positive test charge in an electric field. I will be doing use using vector fields (and plotting the field lines generically) and hopefully making this a dynamic simulation as I progress through the topic (incorporating new parts of this).

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive

# %%
def plot(a, b):
    ''' Centre Charge '''
    A_pos = np.array([a,b])
    A_charge = 1.6e-19 # electron

    ''' Constants '''
    pi = np.pi
    epsilon_nought = 8.85e-12

    def electric_field_strength(pos):
        ''' Need to include conditions for positive and negative charge to be handled automatically '''
        d_sqrd = np.linalg.norm(pos) ** 2
        electric_field_strength = (A_charge) / (4 * pi * epsilon_nought * d_sqrd)
        vector_direction = np.array(pos) - A_pos
        norm_vec = vector_direction / np.linalg.norm(vector_direction)
        return electric_field_strength, norm_vec

    for i in range(1000):
        B = [np.random.uniform(-3,3), np.random.uniform(-3,3)]
        efs, nv = electric_field_strength(B)
        B_quiv = B + nv
        plt.quiver(B[0], B[1], B_quiv[0], B_quiv[1], width=0.002)

    plt.scatter(A_pos[0], A_pos[1])
    plt.grid(alpha=0.2)
    plt.show()

# %%
plot = interactive(plot, a=(-3,3), b=(-3,3))
output = plot.children[-1]
plot
# Out:
# interactive(children=(IntSlider(value=0, description='a', max=3, min=-3), IntSlider(value=0, description='b', …

# %% [markdown]
# The above shows success with a simple, static version of this with a single point charge at the centre. My intention holistically would be for this to progress with multiple point charges and trying to visualise the interacting vector fields.
#
# Finally, the goal would be to have this be dynamic (with sliders in colab or the mouse pointer in Thonny) so see its reaction live to changes in inputs.
